# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline

# %% [markdown]
# #### Node Attributes
# 1. Outfacing Edge
# 2. Infacing Edge
# 3. What can be estimated (Object of node's estimates about  another node)
# 4. What can be controlled  (Object)
# 5. In bandwidth constraint
# 6. Out bandwidth contraint
# 7. List of messages a node has
# 8. Message Sizes
# 8. Storage Capacity for each node
# 8. Proximity Order

# %% [markdown]
# Edge bandwidth constraint should be min(inbound bandwidth at j, outbound bandwidth at i)

# %%
from src.sim import run
# Out:
# [{'N': 3, 'T': range(0, 182), 'M': {'block_time': 30, 'i_storage': 500, 'i_in_bandwidth': 500, 'i_out_bandwidth': 140, 'j_storage': 500, 'j_in_bandwidth': 400, 'j_out_bandwidth': 100, 'p_storage': 4000, 'p_in_bandwidth': 400, 'p_out_bandwidth': 600, 'k_storage': 8000, 'k_in_bandwidth': 400, 'k_out_bandwidth': 80, 'j_avail_to_i': 0.9, 'k_avail_to_i': 0.8, 'j_avail_to_k': 0.7, 'p_avail_to_i': 0.6, 'depth': 15}}, {'N': 3, 'T': range(0, 182), 'M': {'block_time': 30, 'i_storage': 500, 'i_in_bandwidth': 1234, 'i_out_bandwidth': 140, 'j_storage': 500, 'j_in_bandwidth': 400, 'j_out_bandwidth': 100, 'p_storage': 4000, 'p_in_bandwidth': 400, 'p_out_bandwidth': 600, 'k_storage': 8000, 'k_in_bandwidth': 400, 'k_out_bandwidth': 80, 'j_avail_to_i': 0.9, 'k_avail_to_i': 0.8, 'j_avail_to_k': 0.7, 'p_avail_to_i': 0.6, 'depth': 15}}]
# [{'N': 3, 'T': range(0, 182), 'M': {'block_time': 30, 'i_storage': 500, 'i_in_bandwidth': 500, 'i_out_bandwidth': 140, 'j_storage': 500, 'j_in_bandwidth': 400, 'j_out_bandwidth': 100, 'p_storage': 4000, 'p_in_bandwidth': 400, 'p_out_bandwidth': 600, 'k_storage': 8000, 'k_in_bandwidth': 400, 'k_out_bandwidth': 80, 'j_avail_to_i': 0.9, 'k_avail_to_i': 0.8, 'j_avail_to_k': 0.7, 'p_avail_to_i': 0.6, 'depth': 15}}, {'N': 3, 'T': range(0, 182), 'M': {'block_time': 30, 'i_storage': 500, 'i_in_bandwidth': 1234, 'i_out_bandwidth': 140, 'j_storage': 500, 'j_in_bandwidth': 400, 'j_out_bandwidth': 100, 'p_storage': 4000, 'p_in_bandwidth': 400, 'p_out_bandwidth': 600, 'k_storage': 8000, 'k_in_bandwidth': 400, 'k_out_bandwidth': 80, 'j_avail_to_i': 0.9, 'k_avail_to_i': 0.8, 'j_avail_to_k': 0.7, 'p_avail_to_i': 0.6, 'depth': 15}}]

# %%
experiments = run.run()
# Out:
#                             __________   ____
#           ________ __ _____/ ____/   |  / __ \
#          / ___/ __` / __  / /   / /| | / / / /
#         / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
#         \___/\__,_/\__,_/\____/_/  |_/_____/
#         by BlockScience
#
# Execution Mode: multi_proc: [<cadCAD.configuration.Configuration object at 0x0000026D0FB432E8>, <cadCAD.configuration.Configuration object at 0x0000026D0FB43320>]
# Configurations: [<cadCAD.configuration.Configuration object at 0x0000026D0FB432E8>, <cadCAD.configuration.Configuration object at 0x0000026D0FB43320>]

# %%
print(experiments)
# Out:
#    index  block_time  i_storage  i_in_bandwidth  i_out_bandwidth  j_storage  \
# 0      0          30        500             500              140        500
# 1      0          30        500            1234              140        500
#
#    j_in_bandwidth  j_out_bandwidth  p_storage  p_in_bandwidth  \
# 0             400              100       4000             400
# 1             400              100       4000             400
#
#    p_out_bandwidth  k_storage  k_in_bandwidth  k_out_bandwidth  j_avail_to_i  \
# 0              600       8000             400               80           0.9
# 1              600       8000             400               80           0.9
#
#    k_avail_to_i  j_avail_to_k  p_avail_to_i  depth  \
# 0           0.8           0.7           0.6     15
# 1           0.8           0.7           0.6     15
#
#                                              dataset
# 0        timestamp message_array  \
# 0    2020-01-...
# 1        timestamp message_array  \
# 0    2020-01-...

# %%
max(experiments.dataset[0]['run'])
# Out:
# 3

# %%
first_exp = experiments.dataset[0]

# %%
end_key = (len(experiments.dataset[0]) / max(experiments.dataset[0]['run']) -1) * max(experiments.dataset[0]['substep'])
end_key = int(end_key)

# %%
first_exp.head()
# Out:
#     timestamp message_array  \
# 0  2020-01-01   [[0, 0, 0]]
# 4  2020-01-01   [[0, 0, 0]]
# 8  2020-01-01   [[0, 0, 0]]
# 12 2020-01-01   [[0, 0, 0]]
# 16 2020-01-01   [[0, 0, 0]]
#
#                                          message_list  \
# 0            [[None, None, None], [None, None, None]]
# 4   [[None, None, None], [None, None, None], [1345...
# 8   [[None, None, None], [None, None, None], [1345...
# 12  [[None, None, None], [None, None, None], [1345...
# 16  [[None, None, None], [None, None, None], [1345...
#
#                                    file_list                demand  \
# 0   [[None, None, None], [None, None, None]]                     0
# 4   [[None, None, None], [None, None, None]]  [1345681920, 111, 1]
# 8   [[None, None, None], [None, None, None]]   [1345680832, 77, 1]
# 12  [[None, None, None], [None, None, None]]   [1345680800, 76, 1]
# 16  [[None, None, None], [None, None, None]]  [1345684736, 199, 1]
#
#                 arrival                           message_arrival  \
# 0                     0  [[None, None, None], [None, None, None]]
# 4   [1345681184, 88, 1]                       [1345680640, 71, 1]
# 8   [1345680640, 71, 1]                       [1345680352, 62, 1]
# 12  [1345680320, 61, 1]                       [1345680736, 74, 1]
# 16  [1345680992, 82, 1]                       [1345680832, 77, 1]
#
#          network  gross_storage_demand  least_storage_demand  test  run  \
# 0   (i, j, k, p)                     0                     0     0    1
# 4   (i, j, k, p)                     0                     0   568    1
# 8   (i, j, k, p)                   188                   188   248    1
# 12  (i, j, k, p)                   264                   264   592    1
# 16  (i, j, k, p)                   463                   463     0    1
#
#     substep  timestep
# 0         0         0
# 4         4         1
# 8         4         2
# 12        4         3
# 16        4         4

# %%
def draw_net(end_index):
    G = experiments.dataset[0]['network'][end_index]
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, node_size=700)
    nx.draw_networkx_edges(G, pos, width=4)
    nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')
    plt.axis('off')
    return plt.show()

# %%
# get end keys for each run
N = max(experiments.dataset[0]['run'])
key_vals = []
for n in range(1,N+1):
    subs = max(experiments.dataset[0]['substep'])
    times = max(experiments.dataset[0]['timestep'])
    if n == 0:
        number = n*subs*times
    number = n*subs*times + (n-1)
    key_vals.append(number)

# %%
for x in key_vals:
    draw_net(x)

# %%
experiments.dataset[1]['network'][end_key].adj['i']
# Out:
# AtlasView({'j': {'traffic': 740}, 'k': {'traffic': 0}})

# %%
key_vals
# Out:
# [728, 1457, 2186]

# %%
# by_run = experiments.dataset[1].groupby(['run'])
# by_run['network'].head()

# %%
# traffic =np.zeros(1)

# for x in key_vals:
#     run_start = 
#     n=0
#     if n <= x:
#         for n in range(0,x,4):
#             i_to_k = experiments.dataset[1]['network'][n].adj['i']['k']['traffic']
#             i_to_j = experiments.dataset[1]['network'][n].adj['i']['j']['traffic']
#             total = i_to_k + i_to_j
#             traffic = np.vstack((traffic,total))

# %%
traffic =np.zeros(1)
traffic2 =np.zeros(1)
traffic3 =np.zeros(1)

ftraffic =np.zeros(1)
ftraffic2 =np.zeros(1)
ftraffic3 =np.zeros(1)

for n in range(0,728,4):
    i_to_k = experiments.dataset[1]['network'][n].adj['i']['k']['traffic']
    i_to_j = experiments.dataset[1]['network'][n].adj['i']['j']['traffic']
    k_to_j = experiments.dataset[1]['network'][n].adj['k']['j']['traffic']
    total = i_to_k + i_to_j + k_to_j 
    traffic = np.vstack((traffic,total))
    ftotal = experiments.dataset[1]['test'][n] + i_to_k + i_to_j + k_to_j 
    ftraffic  = np.vstack((ftraffic,ftotal))
    
for n in range(733,1457,4):
    i_to_k = experiments.dataset[1]['network'][n].adj['i']['k']['traffic']
    i_to_j = experiments.dataset[1]['network'][n].adj['i']['j']['traffic']
    k_to_j = experiments.dataset[1]['network'][n].adj['k']['j']['traffic']
    total = i_to_k + i_to_j + k_to_j 
    traffic2 = np.vstack((traffic2,total))
    ftotal = experiments.dataset[1]['test'][n] + i_to_k + i_to_j + k_to_j 
    ftraffic2  = np.vstack((ftraffic2,ftotal))

for n in range(1458,2186,4):
    i_to_k = experiments.dataset[1]['network'][n].adj['i']['k']['traffic']
    i_to_j = experiments.dataset[1]['network'][n].adj['i']['j']['traffic']
    k_to_j = experiments.dataset[1]['network'][n].adj['k']['j']['traffic']
    total = i_to_k + i_to_j + k_to_j 
    traffic3 = np.vstack((traffic3,total))
    ftotal = experiments.dataset[1]['test'][n] + i_to_k + i_to_j + k_to_j 
    ftraffic3  = np.vstack((ftraffic3,ftotal))

# %%
plt.figure(figsize=(10,6))
plt.plot(traffic)
plt.plot(traffic2)
plt.plot(traffic3)
plt.plot(ftraffic)
plt.plot(ftraffic2)
plt.plot(ftraffic3)
plt.title('Iterative Kademlia')
plt.xlabel('Time')
plt.ylabel('Traffic per Time')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(traffic)
plt.plot(traffic2)
plt.plot(traffic3)

plt.title('Iterative Kademlia')
plt.xlabel('Time')
plt.ylabel('Traffic per Time')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ftraffic)
plt.plot(ftraffic2)
plt.plot(ftraffic3)
plt.title('Forwarding Kademlia')
plt.xlabel('Time')
plt.ylabel('Traffic per Time')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(traffic.cumsum())
plt.plot(traffic2.cumsum())
plt.plot(traffic3.cumsum())

plt.title('Iterative Kademlia')

plt.yscale('log')
plt.xlabel('Time')
plt.ylabel('Total Traffic')
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(ftraffic.cumsum())
plt.plot(ftraffic2.cumsum())
plt.plot(ftraffic3.cumsum())
plt.title('Forwarding Kademlia')

plt.yscale('log')
plt.xlabel('Days')
plt.ylabel('Total Traffic')
plt.show()

# %%
time_ten = max(experiments.dataset[0]['substep']) * 10
experiments.dataset[0]['network'][time_ten]

# %%
experiments.dataset[1]['test']
# Out:
# 0         0
# 4       368
# 8       220
# 12      272
# 16      280
#        ...
# 2170    220
# 2174    220
# 2178    252
# 2182      0
# 2186      0
# Name: test, Length: 549, dtype: int64

# %%
# nunique = experiments[[item for item in experiments.columns if item not in ['dataset']]].applymap(str).apply(pd.Series.nunique)
# cols_to_drop = nunique[nunique == 1].index
# experiments_full = experiments.copy()
# experiments = experiments.drop(cols_to_drop, axis=1)
# experiments = experiments_full

# %%
experiments.head()
# Out:
#    index  block_time  i_storage  i_in_bandwidth  i_out_bandwidth  j_storage  \
# 0      0          30        500             500              140        500
# 1      0          30        500            1234              140        500
#
#    j_in_bandwidth  j_out_bandwidth  p_storage  p_in_bandwidth  \
# 0             400              100       4000             400
# 1             400              100       4000             400
#
#    p_out_bandwidth  k_storage  k_in_bandwidth  k_out_bandwidth  j_avail_to_i  \
# 0              600       8000             400               80           0.9
# 1              600       8000             400               80           0.9
#
#    k_avail_to_i  j_avail_to_k  p_avail_to_i  depth  \
# 0           0.8           0.7           0.6     15
# 1           0.8           0.7           0.6     15
#
#                                              dataset
# 0        timestamp message_array  \
# 0    2020-01-...
# 1        timestamp message_array  \
# 0    2020-01-...

# %%
end_of_first_experiment = experiments.dataset[0]

# %%
# Remove None from message list
message_list = list(filter(any, experiments.dataset[0]['message_list'][end_key])) 
# message_list = [i for i in experiments.dataset[0]['message_list'][540] if i] 
message_list[0:15]
# Out:
# [[1345681920, 111, 1],
#  [1345680832, 77, 1],
#  [1345680800, 76, 5],
#  [1345684736, 199, 3],
#  [1345683968, 175, 1],
#  [1345680416, 64, 1],
#  [1345681568, 100, 3],
#  [1345680896, 79, 3],
#  [1345679936, 49, 1],
#  [1345682816, 139, 1],
#  [1345684064, 178, 3],
#  [1345680384, 63, 7],
#  [1345678656, 9, 1],
#  [1345679744, 43, 1],
#  [1345680992, 82, 7]]

# %%
experiments.dataset[0]['network'][time_ten].nodes['i']['current_capacity']
# Out:
# 463

# %%
message_array = np.array(message_list[0:5])
message_array
# Out:
# array([[1345681920,        111,          1],
#        [1345680832,         77,          1],
#        [1345680800,         76,          5],
#        [1345684736,        199,          3],
#        [1345683968,        175,          1]])

# %%
# Lower limit of Message Storage Demand , No Double Storage
message_array[:,1].sum()
# Out:
# 638

# %%
message_array[:,1:2].prod()
# Out:
# 1146508420

# %%
np.multiply(message_array[:,1], message_array[:,2])
# Out:
# array([111,  77, 380, 597, 175])

# %%
np.sum(np.multiply(message_array[:,1], message_array[:,2]))
# Out:
# 1340

# %%
experiments.dataset[0]['arrival'][time_ten]
# Out:
# [1345678400, 1, 1]

# %%
experiments.dataset[0]['demand'][time_ten]
# Out:
# [1345682816, 139, 1]

# %%
experiments.dataset[0]['least_storage_demand'][time_ten]
# Out:
# 1069

# %%
experiments.dataset[0]['network'][end_key].nodes['i']
# Out:
# {'neighbor_estimate': {'j_avail_to_i': array([0.97]),
#   'k_avail_to_i': array([0.94]),
#   'p_avail_to_i': [0.6]},
#  'storage_capacity': [500],
#  'current_storage': [[None, None, None],
#   [None, None, None],
#   [1345681920, 111, 1],
#   [1345680832, 77, 1],
#   [1345680800, 76, 5],
#   [1345684736, 199, 3],
#   [1345678656, 9, 1],
#   [1345678528, 5, 1],
#   [1345678464, 3, 3],
#   [1345678688, 10, 3],
#   [1345678592, 7, 1],
#   [1345678432, 2, 1],
#   [1345678400, 1, 1]],
#  'current_capacity': 500,
#  'inband': 500,
#  'outband': [140],
#  'message_history': [[None, None, None], [None, None, None]],
#  'control': [],
#  'id': 8,
#  'routing_table': [['i', 8, '0b1000', 0],
#   ['j', 9, '0b1001', 1],
#   ['k', 11, '0b1011', 3],
#   ['p', 12, '0b1100', 4]]}

# %%
experiments.dataset[1]['network'][end_key].nodes['i']
# Out:
# {'neighbor_estimate': {'j_avail_to_i': array([0.96]),
#   'k_avail_to_i': array([0.87]),
#   'p_avail_to_i': [0.6]},
#  'storage_capacity': [500],
#  'current_storage': [[None, None, None],
#   [None, None, None],
#   [1345683776, 169, 3],
#   [1345678400, 1, 5],
#   [1345682016, 114, 3],
#   [1345679264, 28, 1],
#   [1345681248, 90, 1],
#   [1345678496, 4, 5],
#   [1345680448, 65, 1],
#   [1345678528, 5, 5],
#   [1345679008, 20, 5],
#   [1345678464, 3, 1]],
#  'current_capacity': 499,
#  'inband': 1234,
#  'outband': [140],
#  'message_history': [[None, None, None], [None, None, None]],
#  'control': [],
#  'id': 8,
#  'routing_table': [['i', 8, '0b1000', 0],
#   ['j', 9, '0b1001', 1],
#   ['k', 11, '0b1011', 3],
#   ['p', 12, '0b1100', 4]]}

# %%
experiments.dataset[1]['network'][end_key].nodes['j']
# Out:
# {'neighbor_estimate': {'storage from i': 7,
#   'storage from k': 0,
#   'messages from i': 0,
#   'messages from k': 16},
#  'storage_capacity': [500],
#  'current_storage': [[None, None, None],
#   [None, None, None],
#   [1345682720, 136, 1],
#   [1345684480, 191, 3],
#   [1345680896, 79, 1],
#   [1345680000, 51, 3],
#   [1345679680, 41, 1]],
#  'current_capacity': 498,
#  'inband': [400],
#  'outband': [100],
#  'message_history': [[None, None, None],
#   [None, None, None],
#   [1345679840, 46, 1],
#   [0, 0, 5],
#   [1345679456, 34, 1],
#   [1345679488, 35, 1],
#   [1345680000, 51, 1],
#   [1345679648, 40, 1],
#   [1345679232, 27, 1],
#   [1345679520, 36, 1],
#   [1345678624, 8, 1],
#   [1345679712, 42, 1],
#   [1345679904, 48, 1],
#   [1345679072, 22, 1]],
#  'control': [],
#  'id': 9,
#  'routing_table': [['i', 8, '0b1000', 1],
#   ['j', 9, '0b1001', 0],
#   ['k', 11, '0b1011', 2],
#   ['p', 12, '0b1100', 5]]}

# %%
experiments.dataset[1]['network'][end_key].nodes['k']
# Out:
# {'neighbor_estimate': {'storage from i': 116,
#   'messages from i': 182,
#   'j_avail_to_k': array([0.81])},
#  'storage_capacity': [8000],
#  'current_storage': [[None, None, None],
#   [None, None, None],
#   [1345681504, 98, 1],
#   [1345684352, 187, 3],
#   [1345682080, 116, 3],
#   [1345681600, 101, 3],
#   [1345681824, 108, 5],
#   [1345683872, 172, 7],
#   [1345680288, 60, 1],
#   [1345679936, 49, 5],
#   [1345681760, 106, 1],
#   [1345680192, 57, 1],
#   [1345679488, 35, 1],
#   [1345679584, 38, 1],
#   [1345683904, 173, 1],
#   [1345679776, 44, 5],
#   [1345680480, 66, 1],
#   [1345683712, 167, 1],
#   [1345684096, 179, 3],
#   [1345682784, 138, 1],
#   [1345684000, 176, 1],
#   [1345678976, 19, 1],
#   [1345684736, 199, 1],
#   [1345681280, 91, 5],
#   [1345678688, 10, 3],
#   [1345680832, 77, 3],
#   [1345683072, 147, 1],
#   [1345680608, 70, 1],
#   [1345680416, 64, 3],
#   [1345684320, 186, 1],
#   [1345682464, 128, 1],
#   [1345682880, 141, 5],
#   [1345684160, 181, 1],
#   [1345682048, 115, 3],
#   [1345682112, 117, 1],
#   [1345683744, 168, 1],
#   [1345681792, 107, 3],
#   [1345683616, 164, 5],
#   [1345681408, 95, 3],
#   [1345679616, 39, 3],
#   [1345679328, 30, 1],
#   [1345682176, 119, 5],
#   [1345683552, 162, 1],
#   [1345680352, 62, 3],
#   [1345682272, 122, 1],
#   [1345682240, 121, 1],
#   [1345684192, 182, 1],
#   [1345683584, 163, 5],
#   [1345679040, 21, 3],
#   [1345683296, 154, 3],
#   [1345681856, 109, 1],
#   [1345683808, 170, 1],
#   [1345682528, 130, 7],
#   [1345678560, 6, 1],
#   [1345684608, 195, 1],
#   [1345678720, 11, 3],
#   [1345679712, 42, 1],
#   [1345680768, 75, 1],
#   [1345682144, 118, 1],
#   [1345682336, 124, 3],
#   [1345683424, 158, 1],
#   [1345683168, 150, 1],
#   [1345681184, 88, 1],
#   [1345683104, 148, 1],
#   [1345683232, 152, 1],
#   [1345681536, 99, 1],
#   [1345684384, 188, 1],
#   [1345679904, 48, 1],
#   [1345682496, 129, 1],
#   [1345680576, 69, 1],
#   [1345679360, 31, 1],
#   [1345680704, 73, 3],
#   [1345679648, 40, 1],
#   [1345681440, 96, 3],
#   [1345678752, 12, 1],
#   [1345680544, 68, 1],
#   [1345682368, 125, 1],
#   [1345678816, 14, 1]],
#  'current_capacity': 7992,
#  'inband': [400],
#  'outband': [80],
#  'message_history': [[None, None, None],
#   [None, None, None],
#   [1345679840, 46, 1],
#   [1345680128, 55, 1],
#   [1345679456, 34, 1],
#   [1345679488, 35, 1],
#   [1345680736, 74, 1],
#   [1345680000, 51, 1],
#   [0, 0, 176]],
#  'control': [],
#  'id': 11,
#  'routing_table': [['i', 8, '0b1000', 3],
#   ['j', 9, '0b1001', 2],
#   ['k', 11, '0b1011', 0],
#   ['p', 12, '0b1100', 7]]}

# %%
draw_net(end_key)

# %%
# End network State
G = experiments.dataset[1]['network'][end_key]
pos = nx.spring_layout(G)

# %%
#nx.draw(G)
nx.draw_networkx_nodes(G, pos, node_size=700)
nx.draw_networkx_edges(G, pos, width=4)
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')
plt.axis('off')
plt.show()

# %%
def message_metrics(node_name):
    i_message_list = list(filter(any, experiments.dataset[1]['network'][end_key].nodes[str(node_name)]['current_storage'])) 
    # convert to array
    i_message_array = np.array(i_message_list)
    #print(message_array)
    # sum of sizes of messages without repeats representing the lower bound, if every node only stored the file once
    total = np.nansum(i_message_array[:,1])
    mean = total / len(i_message_array)
    total_freq = np.nansum(i_message_array[:,2])
    freq = total_freq / len(i_message_array)
    
    return print('Node ', node_name, ": Average Stored Size = ", format(mean, ".2f"), ", Average Frequency = ", format(freq, ".2f"))

# %%
message_metrics('i')
message_metrics('j')
message_metrics('k')
# Out:
# Node  i : Average Stored Size =  49.90 , Average Frequency =  3.00
# Node  j : Average Stored Size =  99.60 , Average Frequency =  1.80
# Node  k : Average Stored Size =  105.16 , Average Frequency =  2.05

# %%
storage_efficiency = experiments.dataset[1]['least_storage_demand'][end_key] / experiments.dataset[1]['gross_storage_demand'][end_key]
print("Storage Efficiency = ",format(storage_efficiency, ".1%"))
# Out:
# Storage Efficiency =  54.4%

# %%
def failed_message(node_name):
    message_list = list(filter(any, experiments.dataset[1]['network'][end_key].nodes[str(node_name)]['current_storage'])) 
    # convert to array
    message_array = np.array(message_list)
    fail_message = np.where(message_array[:,0] == 0)
    fail_count = message_array[fail_message,2]
    if fail_count.size == 0:
        fail_count = 0
    else:
        fail_count = fail_count[0][0]
    return print("Node ", node_name, ": Failed Messages =", fail_count)

# %%
failed_message('i')
failed_message('j')
failed_message('k')
# Out:
# Node  i : Failed Messages = 0
# Node  j : Failed Messages = 0
# Node  k : Failed Messages = 0

# %%
experiments.dataset[1]['network'][end_key].adj['i']
# Out:
# AtlasView({'j': {'traffic': 740}, 'k': {'traffic': 0}})

# %%
experiments.dataset[1]['network'][end_key].adj['k']
# Out:
# AtlasView({'j': {'traffic': 22}})

# %%
G = experiments.dataset[1]['network'][time_ten]

uppest_traffic = [(u, v) for (u, v, d) in G.edges(data=True) if d['traffic'] > 75]
upper_traffic = [(u, v) for (u, v, d) in G.edges(data=True) if 75 > d['traffic'] > 50]
lower_traffic = [(u, v) for (u, v, d) in G.edges(data=True) if 50 > d['traffic'] > 25]
lowest_traffic = [(u, v) for (u, v, d) in G.edges(data=True) if d['traffic'] < 25]

pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=700)
# for i in edge_traffic:
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')    
# nx.draw_networkx_edges(G, pos, width=1, edge_list=lowest_traffic, edge_color='g')
# nx.draw_networkx_edges(G, pos, width=7, edge_list=uppest_traffic, edge_color='b')
nx.draw_networkx_edges(G, pos, width=5, edge_list=upper_traffic)
# nx.draw_networkx_edges(G, pos, edge_list=lower_traffic)




plt.axis('off')
plt.show()

# %%
 G.edges
# Out:
# OutEdgeView([('i', 'j'), ('i', 'k'), ('j', 'p'), ('k', 'j')])

# %%
for (u, v, d) in G.edges(data=True):
    print(d['traffic'])
# Out:
# 406
# 0
# 0
# 0

# %%
# edge_color=colors,
#         width=4, edge_cmap=plt.cm.Blues, with_labels=False

# %%
uppest_traffic
# Out:
# [('i', 'j')]

# %%
upper_traffic
# Out:
# []

# %%
lowest_traffic
# Out:
# [('i', 'k'), ('j', 'p'), ('k', 'j')]

# %%
temp_list = [1,2,3]

# %%
temp_list.copy()
# Out:
# [1, 2, 3]
